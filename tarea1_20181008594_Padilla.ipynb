# %% [markdown]
# # Creacion del DataFrame utilizando valores aleatorios.
# ## tiende de venta de telefonos

# %% [markdown]
# ## 1 items del para llenar el DataFrame

# %%
import pandas as pd
import random
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Itemsproductos = ['Iphone 13 Pro Max', 'Iphone 14 Pro Max', 'Iphone 15 Pro Max', 'Iphone 11 Pro','Iphone X Pro']
Itemsvendedores = ['Juan Jose', 'Belinda Sofia', 'David Alejandro', 'Pedro Leonel']
Itemsregiones = ['Centro', 'Anillo Periferico', 'BFFA', 'La Laguna']

# %% [markdown]
# ## 2 Generado de Datos Aleatorios

# %%
cantidad_datos=3000

# %%
producto = random.choices(productos, k=cantidad_datos)
vendedor= random.choices(vendedores, k=cantidad_datos)
region= random.choices(regiones, k=cantidad_datos)

cantidad=[]
precio_unitario=[]
precio_total=[]

for i in range(cantidad_datos):
    cantidad.append( random.randint(1, 100))

for i in range(cantidad_datos):
    precio_unitario.append( round(random.uniform(5.0, 100.0), 2))
    
fecha= pd.date_range(start='2023-01-01', periods=cantidad_datos, freq='D').tolist()

for i in range(cantidad_datos):
    precio_total.append(cantidad[i]* precio_unitario[i])

# %% [markdown]
# ## 3 Creacion del DataFrame

# %%
df = pd.DataFrame({
    'producto': producto,
    'vendedor': vendedor,
    'region': region,
    'cantidad': cantidad,
    'precio_unitario': precio_unitario,
    'fecha': fecha,
    'precio_total': precio_total
})

# %%
df
# Out:
#                producto         vendedor             region  cantidad  \
# 0          Iphone X Pro    Belinda Sofia  Anillo Periferico        90
# 1     Iphone 15 Pro Max  David Alejandro  Anillo Periferico        60
# 2     Iphone 15 Pro Max  David Alejandro             Centro        12
# 3     Iphone 15 Pro Max    Belinda Sofia  Anillo Periferico         8
# 4         Iphone 11 Pro    Belinda Sofia               BFFA         9
# ...                 ...              ...                ...       ...
# 2995  Iphone 14 Pro Max    Belinda Sofia          La Laguna        32
# 2996      Iphone 11 Pro    Belinda Sofia  Anillo Periferico        74
# 2997  Iphone 13 Pro Max    Belinda Sofia               BFFA        77
# 2998  Iphone 14 Pro Max        Juan Jose  Anillo Periferico        89
# 2999       Iphone X Pro        Juan Jose               BFFA        19
#
#       precio_unitario      fecha  precio_total
# 0               71.50 2023-01-01       6435.00
# ...

# %% [markdown]
# ## Resumenes estadisticos

# %%
df.describe()
# Out:
#           cantidad  precio_unitario                fecha  precio_total
# count  3000.000000      3000.000000                 3000   3000.000000
# mean     50.610667        52.390653  2027-02-08 12:00:00   2628.162040
# min       1.000000         5.000000  2023-01-01 00:00:00     14.780000
# 25%      26.000000        28.365000  2025-01-19 18:00:00    835.462500
# 50%      50.000000        52.510000  2027-02-08 12:00:00   2010.660000
# 75%      76.000000        75.982500  2029-02-27 06:00:00   3894.982500
# max     100.000000        99.960000  2031-03-19 00:00:00   9988.000000
# std      28.835908        27.590263                  NaN   2177.292481

# %%
df.describe(include=['O'])
# Out:
#                  producto         vendedor region
# count                3000             3000   3000
# unique                  5                4      4
# top     Iphone 13 Pro Max  David Alejandro   BFFA
# freq                  619              781    767

# %% [markdown]
# ## 4 Visualizar los Datos usando matplotlib y seaborn

# %%
plt.figure(figsize=(12, 8))

plt.subplot(2, 2, 1)
sns.histplot(df['cantidad'], bins=30, kde=True)
plt.title('Distribución de Cantidad')

plt.subplot(2, 2, 2)
sns.histplot(df['precio_unitario'], bins=30, kde=True)
plt.title('Distribución de Precio Unitario')

plt.subplot(2, 2, 3)
sns.histplot(df['precio_total'], bins=10, kde=True)
plt.title('Distribución de Precio Total')

plt.subplot(2, 2, 4)
sns.histplot(df['vendedor'] )
plt.title('Distribución de los Vendedores')

plt.tight_layout()
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...
